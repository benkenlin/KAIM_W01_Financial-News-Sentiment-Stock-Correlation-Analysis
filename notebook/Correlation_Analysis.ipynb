# %% [markdown]
# # Imports and Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Import your custom modules
import sys
sys.path.append('../src') # Add src directory to Python path
from data_loader import load_all_historical_data
from news_processor import load_financial_news_data, add_sentiment_score
from financial_metrics import add_daily_returns # We will specifically use daily returns here

# Configure plot styles
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 8)
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# # Load and Prepare News Data (Sentiment Analysis)

# %%
print("--- Loading and Processing News Data ---")
df_news = load_financial_news_data(filepath='../data/cleaned_analyst_ratings.csv')

if df_news.empty:
    print("News data not loaded or is empty. Please check 'financial_news.csv' and data_loader.py.")
else:
    df_news_sentiment = add_sentiment_score(df_news.copy()) # Use a copy to avoid modifying original df_news
    print("\nNews data with sentiment scores:")
    print(df_news_sentiment[['date', 'stock', 'headline', 'sentiment_score']].head())

    # Aggregate sentiment by day for each stock
    # We will use the mean sentiment for simplicity, but median or sum could also be considered.
    daily_avg_sentiment = df_news_sentiment.groupby(['publication_day', 'stock'])['sentiment_score'].mean().reset_index()
    daily_avg_sentiment.rename(columns={'publication_day': 'Date', 'sentiment_score': 'daily_avg_sentiment'}, inplace=True)
    daily_avg_sentiment['Date'] = pd.to_datetime(daily_avg_sentiment['Date']) # Ensure datetime type for merging

    print("\nDaily aggregated sentiment per stock:")
    print(daily_avg_sentiment.head())
# Out:
# --- Loading and Processing News Data ---
# Loaded financial news data from ../data/cleaned_analyst_ratings.csv
#
# News data with sentiment scores:
#                        date stock  \
# 0 2020-06-05 14:30:54+00:00     A
# 1 2020-06-03 14:45:20+00:00     A
# 2 2020-05-26 08:30:07+00:00     A
# 3 2020-05-22 16:45:06+00:00     A
# 4 2020-05-22 15:38:59+00:00     A
#
#                                             headline  sentiment_score
# 0            Stocks That Hit 52-Week Highs On Friday             0.16
# 1         Stocks That Hit 52-Week Highs On Wednesday             0.16
# 2                      71 Biggest Movers From Friday             0.00
# 3       46 Stocks Moving In Friday's Mid-Day Session             0.00
# 4  B of A Securities Maintains Neutral on Agilent...             0.00
#
# Daily aggregated sentiment per stock:
#                        Date stock  daily_avg_sentiment
# 0 2011-04-28 00:00:00+00:00   DEJ             0.000000
# 1 2011-04-28 00:00:00+00:00   DGP             0.000000
# 2 2011-04-28 00:00:00+00:00   ESR             0.136364
# 3 2011-04-29 00:00:00+00:00   AIA            -0.166667
# 4 2011-04-29 00:00:00+00:00   GDL             0.500000

# %% [markdown]
# # Load and Prepare Stock Price Data

# %%
print("\n--- Loading and Processing Stock Historical Data ---")
all_stock_data = load_all_historical_data(data_dir='../data/yfinance_data')

processed_stock_returns = {}
for ticker, df_hist in all_stock_data.items():
    if df_hist.empty:
        print(f"Skipping {ticker}: Historical data is empty.")
        continue  
    # Calculate daily stock returns
    df_hist_with_returns = add_daily_returns(df_hist.copy())
    
    # Ensure 'Date' index is standardized to match news 'Date' for merging
    df_hist_with_returns.index = df_hist_with_returns.index.normalize() # Remove time component if present
    df_hist_with_returns.index.name = 'Date' # Ensure index name is 'Date' for merging

    processed_stock_returns[ticker] = df_hist_with_returns[['Close', 'Daily_Return']] # Keep relevant columns
    print(f"Processed daily returns for {ticker}.")

print("\nExample: AAPL Daily Returns Head:")
if 'AAPL' in processed_stock_returns:
    print(processed_stock_returns['AAPL'].head())
# Out:
# --- Loading and Processing Stock Historical Data ---
#
# Example: AAPL Daily Returns Head:

# %% [markdown]
# # Merge Datasets (Data Alignment)

# %%
print("\n--- Merging News Sentiment and Stock Returns ---")
merged_data_for_correlation = {}

unique_tickers = daily_avg_sentiment['stock'].unique()

for ticker in unique_tickers:
    news_sentiment_for_ticker = daily_avg_sentiment[daily_avg_sentiment['stock'] == ticker]
    stock_returns_for_ticker = processed_stock_returns.get(ticker)

    if stock_returns_for_ticker is None or stock_returns_for_ticker.empty:
        print(f"No stock data found or empty for {ticker}. Skipping merge.")
        continue

    # Perform the merge. Using 'inner' join ensures only matching dates are kept.
    # This aligns the news sentiment for a given day with the stock's return on that same day.
    # Note: If news impacts *next day's* return, we'd shift the stock returns.
    df_merged = pd.merge(
        news_sentiment_for_ticker,
        stock_returns_for_ticker,
        on='Date',
        how='inner'
    )
    
    if not df_merged.empty:
        # Drop the first row of Daily_Return as it will be NaN due to pct_change()
        df_merged.dropna(subset=['Daily_Return'], inplace=True)
        if not df_merged.empty:
            merged_data_for_correlation[ticker] = df_merged
            print(f"Merged data for {ticker}. Rows: {len(df_merged)}")
        else:
            print(f"Merged data for {ticker} resulted in empty DataFrame after dropping NaNs.")
    else:
        print(f"No overlapping dates for {ticker} between news sentiment and stock returns.")

print("\nExample: Merged data for AAPL head (sentiment and returns):")
if 'AAPL' in merged_data_for_correlation:
    print(merged_data_for_correlation['AAPL'].head())
# Out:
# --- Merging News Sentiment and Stock Returns ---
# No stock data found or empty for DEJ. Skipping merge.
# No stock data found or empty for DGP. Skipping merge.
# No stock data found or empty for ESR. Skipping merge.
# No stock data found or empty for AIA. Skipping merge.
# No stock data found or empty for GDL. Skipping merge.
# No stock data found or empty for PTM. Skipping merge.
# No stock data found or empty for DBP. Skipping merge.
# No stock data found or empty for AGOL. Skipping merge.
# No stock data found or empty for DGZ. Skipping merge.
# No stock data found or empty for GLTR. Skipping merge.
# No stock data found or empty for PSQ. Skipping merge.
# No stock data found or empty for SCJ. Skipping merge.
# No stock data found or empty for SZO. Skipping merge.
# No stock data found or empty for TLH. Skipping merge.
# No stock data found or empty for WITE. Skipping merge.
# No stock data found or empty for CSM. Skipping merge.
# No stock data found or empty for NIM. Skipping merge.
# No stock data found or empty for LTL. Skipping merge.
# No stock data found or empty for MHF. Skipping merge.
# No stock data found or empty for NLR. Skipping merge.
# No stock data found or empty for EMI. Skipping merge.
# No stock data found or empty for WOOD. Skipping merge.
# No stock data found or empty for FUE. Skipping merge.
# No stock data found or empty for FXR. Skipping merge.
# No stock data found or empty for BRAF. Skipping merge.
# No stock data found or empty for EDIV. Skipping merge.
# No stock data found or empty for FTC. Skipping merge.
# No stock data found or empty for PWV. Skipping merge.
# No stock data found or empty for UGL. Skipping merge.
# No stock data found or empty for BOM. Skipping merge.
# No stock data found or empty for JKF. Skipping merge.
# No stock data found or empty for PSAU. Skipping merge.
# No stock data found or empty for DBS. Skipping merge.
# No stock data found or empty for PXR. Skipping merge.
# No stock data found or empty for TTT. Skipping merge.
# No stock data found or empty for ICI. Skipping merge.
# No stock data found or empty for TLO. Skipping merge.
# No stock data found or empty for TWM. Skipping merge.
# No stock data found or empty for DWX. Skipping merge.
# No stock data found or empty for KROO. Skipping merge.
# No stock data found or empty for SGF. Skipping merge.
# No stock data found or empty for NECB. Skipping merge.
# No stock data found or empty for TBF. Skipping merge.
# No stock data found or empty for WIP. Skipping merge.
# No stock data found or empty for DNO. Skipping merge.
# No stock data found or empty for GTAA. Skipping merge.
# No stock data found or empty for PSK. Skipping merge.
# No stock data found or empty for CCX. Skipping merge.
# No stock data found or empty for CGW. Skipping merge.
# No stock data found or empty for FIW. Skipping merge.
# No stock data found or empty for MOG.B. Skipping merge.
# No stock data found or empty for BDD. Skipping merge.
# No stock data found or empty for ENY. Skipping merge.
# No stock data found or empty for EXI. Skipping merge.
# No stock data found or empty for PCQ. Skipping merge.
# No stock data found or empty for PEZ. Skipping merge.
# No stock data found or empty for PNF. Skipping merge.
# No stock data found or empty for PNI. Skipping merge.
# No stock data found or empty for PZC. Skipping merge.
# No stock data found or empty for IYJ. Skipping merge.
# No stock data found or empty for UCI. Skipping merge.
# No stock data found or empty for FXS. Skipping merge.
# No stock data found or empty for JW.A. Skipping merge.
# No stock data found or empty for DXD. Skipping merge.
# No stock data found or empty for DPK. Skipping merge.
# No stock data found or empty for EMIF. Skipping merge.
# No stock data found or empty for INR. Skipping merge.
# No stock data found or empty for SFN. Skipping merge.
# No stock data found or empty for ISP. Skipping merge.
# No stock data found or empty for LCM. Skipping merge.
# No stock data found or empty for SCD. Skipping merge.
# No stock data found or empty for SDP. Skipping merge.
# No stock data found or empty for CNY. Skipping merge.
# No stock data found or empty for SSO. Skipping merge.
# No stock data found or empty for DNL. Skipping merge.
# No stock data found or empty for FONE. Skipping merge.
# No stock data found or empty for GSP. Skipping merge.
# No stock data found or empty for APSA. Skipping merge.
# No stock data found or empty for DOG. Skipping merge.
# No stock data found or empty for KEF. Skipping merge.
# No stock data found or empty for IND. Skipping merge.
# No stock data found or empty for JYN. Skipping merge.
# No stock data found or empty for PMF. Skipping merge.
# No stock data found or empty for PMX. Skipping merge.
# No stock data found or empty for BWX. Skipping merge.
# No stock data found or empty for DBBR. Skipping merge.
# No stock data found or empty for DBEM. Skipping merge.
# No stock data found or empty for LBF. Skipping merge.
# No stock data found or empty for PICB. Skipping merge.
# No stock data found or empty for PXH. Skipping merge.
# No stock data found or empty for BRAZ. Skipping merge.
# No stock data found or empty for DGL. Skipping merge.
# No stock data found or empty for EVX. Skipping merge.
# No stock data found or empty for USL. Skipping merge.
# No stock data found or empty for DEE. Skipping merge.
# No stock data found or empty for MZZ. Skipping merge.
# No stock data found or empty for EUM. Skipping merge.
# No stock data found or empty for ROOF. Skipping merge.
# No stock data found or empty for SBB. Skipping merge.
# No stock data found or empty for YXI. Skipping merge.
# No stock data found or empty for IPF. Skipping merge.
# No stock data found or empty for UYM. Skipping merge.
# No stock data found or empty for IOIL. Skipping merge.
# No stock data found or empty for PFK. Skipping merge.
# No stock data found or empty for UPV. Skipping merge.
# No stock data found or empty for DJP. Skipping merge.
# No stock data found or empty for FLTR. Skipping merge.
# No stock data found or empty for JJA. Skipping merge.
# No stock data found or empty for RJI. Skipping merge.
# No stock data found or empty for SRS. Skipping merge.
# No stock data found or empty for BSE. Skipping merge.
# No stock data found or empty for DYY. Skipping merge.
# No stock data found or empty for DRW. Skipping merge.
# No stock data found or empty for SCHF. Skipping merge.
# No stock data found or empty for CGO. Skipping merge.
# No stock data found or empty for BIK. Skipping merge.
# No stock data found or empty for BKF. Skipping merge.
# No stock data found or empty for EEB. Skipping merge.
# No stock data found or empty for BWINB. Skipping merge.
# No stock data found or empty for CKX. Skipping merge.
# No stock data found or empty for CYB. Skipping merge.
# No stock data found or empty for EFU. Skipping merge.
# No stock data found or empty for DBO. Skipping merge.
# No stock data found or empty for DBU. Skipping merge.
# No stock data found or empty for DTH. Skipping merge.
# No stock data found or empty for HGI. Skipping merge.
# No stock data found or empty for RWO. Skipping merge.
# No stock data found or empty for WPS. Skipping merge.
# No stock data found or empty for CTV. Skipping merge.
# No stock data found or empty for IPD. Skipping merge.
# No stock data found or empty for CROP. Skipping merge.
# No stock data found or empty for ERO. Skipping merge.
# No stock data found or empty for MGH. Skipping merge.
# No stock data found or empty for GWX. Skipping merge.
# No stock data found or empty for IVW. Skipping merge.
# No stock data found or empty for IWN. Skipping merge.
# No stock data found or empty for REW. Skipping merge.
# No stock data found or empty for FLM. Skipping merge.
# No stock data found or empty for GMF. Skipping merge.
# No stock data found or empty for URR. Skipping merge.
# No stock data found or empty for UBC. Skipping merge.
# No stock data found or empty for PSI. Skipping merge.
# No stock data found or empty for IJT. Skipping merge.
# No stock data found or empty for FAV. Skipping merge.
# No stock data found or empty for PUI. Skipping merge.
# No stock data found or empty for TFG. Skipping merge.
# No stock data found or empty for PSCH. Skipping merge.
# No stock data found or empty for UCD. Skipping merge.
# No stock data found or empty for XMPT. Skipping merge.
# No stock data found or empty for RTM. Skipping merge.
# No stock data found or empty for DOL. Skipping merge.
# No stock data found or empty for PXJ. Skipping merge.
# No stock data found or empty for AIB. Skipping merge.
# No stock data found or empty for CEE. Skipping merge.
# No stock data found or empty for VOT. Skipping merge.
# No stock data found or empty for ESBF. Skipping merge.
# No stock data found or empty for PRB. Skipping merge.
# No stock data found or empty for UBG. Skipping merge.
# No stock data found or empty for USCI. Skipping merge.
# No stock data found or empty for CMSB. Skipping merge.
# No stock data found or empty for RXL. Skipping merge.
# No stock data found or empty for RYH. Skipping merge.
# No stock data found or empty for AGA. Skipping merge.
# No stock data found or empty for PBM. Skipping merge.
# No stock data found or empty for RGI. Skipping merge.
# No stock data found or empty for RYU. Skipping merge.
# No stock data found or empty for FUD. Skipping merge.
# No stock data found or empty for GMK. Skipping merge.
# No stock data found or empty for JJP. Skipping merge.
# No stock data found or empty for SDD. Skipping merge.
# No stock data found or empty for FNI. Skipping merge.
# No stock data found or empty for AFC. Skipping merge.
# No stock data found or empty for DDP. Skipping merge.
# No stock data found or empty for GCC. Skipping merge.
# No stock data found or empty for VBK. Skipping merge.
# No stock data found or empty for CRF. Skipping merge.
# No stock data found or empty for DAG. Skipping merge.
# No stock data found or empty for PSR. Skipping merge.
# No stock data found or empty for RXD. Skipping merge.
# No stock data found or empty for SCC. Skipping merge.
# No stock data found or empty for SMB. Skipping merge.
# No stock data found or empty for DRR. Skipping merge.
# No stock data found or empty for GGE. Skipping merge.
# No stock data found or empty for RIF. Skipping merge.
# No stock data found or empty for GRN. Skipping merge.
# No stock data found or empty for ICF. Skipping merge.
# No stock data found or empty for BABS. Skipping merge.
# No stock data found or empty for BLV. Skipping merge.
# No stock data found or empty for CMF. Skipping merge.
# No stock data found or empty for CXA. Skipping merge.
# No stock data found or empty for DLBL. Skipping merge.
# No stock data found or empty for DTYL. Skipping merge.
# No stock data found or empty for LTPZ. Skipping merge.
# No stock data found or empty for LWC. Skipping merge.
# No stock data found or empty for TIPZ. Skipping merge.
# No stock data found or empty for UBT. Skipping merge.
# No stock data found or empty for UST. Skipping merge.
# No stock data found or empty for GSC. Skipping merge.
# No stock data found or empty for LSC. Skipping merge.
# No stock data found or empty for FVL. Skipping merge.
# No stock data found or empty for PSP. Skipping merge.
# No stock data found or empty for SRTY. Skipping merge.
# No stock data found or empty for BOS. Skipping merge.
# No stock data found or empty for EWV. Skipping merge.
# No stock data found or empty for FFNM. Skipping merge.
# No stock data found or empty for SCHP. Skipping merge.
# No stock data found or empty for FLN. Skipping merge.
# No stock data found or empty for NKY. Skipping merge.
# No stock data found or empty for PFI. Skipping merge.
# No stock data found or empty for KME. Skipping merge.
# No stock data found or empty for DGT. Skipping merge.
# No stock data found or empty for EMSA. Skipping merge.
# No stock data found or empty for SGOL. Skipping merge.
# No stock data found or empty for SKOR. Skipping merge.
# No stock data found or empty for TBAR. Skipping merge.
# No stock data found or empty for EU. Skipping merge.
# No stock data found or empty for FGB. Skipping merge.
# No stock data found or empty for SZK. Skipping merge.
# No stock data found or empty for IWO. Skipping merge.
# No stock data found or empty for VFL. Skipping merge.
# No stock data found or empty for COBK. Skipping merge.
# No stock data found or empty for LVL. Skipping merge.
# No stock data found or empty for APAGF. Skipping merge.
# No stock data found or empty for CVOL. Skipping merge.
# No stock data found or empty for DDG. Skipping merge.
# No stock data found or empty for DIG. Skipping merge.
# No stock data found or empty for KCC. Skipping merge.
# No stock data found or empty for IST. Skipping merge.
# No stock data found or empty for PCM. Skipping merge.
# No stock data found or empty for MYY. Skipping merge.
# No stock data found or empty for RFG. Skipping merge.
# No stock data found or empty for SMDD. Skipping merge.
# No stock data found or empty for JKE. Skipping merge.
# No stock data found or empty for CZA. Skipping merge.
# No stock data found or empty for EZM. Skipping merge.
# No stock data found or empty for JKI. Skipping merge.
# No stock data found or empty for MDD. Skipping merge.
# No stock data found or empty for PIO. Skipping merge.
# No stock data found or empty for UYG. Skipping merge.
# No stock data found or empty for GEF.B. Skipping merge.
# No stock data found or empty for BWZ. Skipping merge.
# No stock data found or empty for GLDX. Skipping merge.
# No stock data found or empty for JJN. Skipping merge.
# No stock data found or empty for GLL. Skipping merge.
# No stock data found or empty for RHS. Skipping merge.
# No stock data found or empty for SCHH. Skipping merge.
# No stock data found or empty for JKG. Skipping merge.
# No stock data found or empty for EFZ. Skipping merge.
# No stock data found or empty for IPU. Skipping merge.
# No stock data found or empty for CCXE. Skipping merge.
# No stock data found or empty for CRV. Skipping merge.
# No stock data found or empty for HUB.A. Skipping merge.
# No stock data found or empty for IFGL. Skipping merge.
# No stock data found or empty for RTR. Skipping merge.
# No stock data found or empty for SAA. Skipping merge.
# No stock data found or empty for SCHE. Skipping merge.
# No stock data found or empty for AAXJ. Skipping merge.
# No stock data found or empty for IPK. Skipping merge.
# No stock data found or empty for KCE. Skipping merge.
# No stock data found or empty for PXQ. Skipping merge.
# No stock data found or empty for SPXU. Skipping merge.
# No stock data found or empty for UPRO. Skipping merge.
# No stock data found or empty for IBND. Skipping merge.
# No stock data found or empty for EVP. Skipping merge.
# No stock data found or empty for PAGG. Skipping merge.
# No stock data found or empty for XPP. Skipping merge.
# No stock data found or empty for IXP. Skipping merge.
# No stock data found or empty for TLL. Skipping merge.
# No stock data found or empty for XES. Skipping merge.
# No stock data found or empty for FOIL. Skipping merge.
# No stock data found or empty for FVD. Skipping merge.
# No stock data found or empty for HDGE. Skipping merge.
# No stock data found or empty for MCRO. Skipping merge.
# No stock data found or empty for BLH. Skipping merge.
# No stock data found or empty for PTF. Skipping merge.
# No stock data found or empty for IGN. Skipping merge.
# No stock data found or empty for MMV. Skipping merge.
# No stock data found or empty for NCA. Skipping merge.
# No stock data found or empty for RWM. Skipping merge.
# No stock data found or empty for TRF. Skipping merge.
# No stock data found or empty for UWM. Skipping merge.
# No stock data found or empty for EOI. Skipping merge.
# No stock data found or empty for OEF. Skipping merge.
# No stock data found or empty for IF. Skipping merge.
# No stock data found or empty for CDC. Skipping merge.
# No stock data found or empty for DSUM. Skipping merge.
# No stock data found or empty for EXT. Skipping merge.
# No stock data found or empty for GCH. Skipping merge.
# No stock data found or empty for IJK. Skipping merge.
# No stock data found or empty for IYY. Skipping merge.
# No stock data found or empty for PLTM. Skipping merge.
# No stock data found or empty for NRO. Skipping merge.
# No stock data found or empty for PGP. Skipping merge.
# No stock data found or empty for PSCE. Skipping merge.
# No stock data found or empty for IBCA. Skipping merge.
# No stock data found or empty for PID. Skipping merge.
# No stock data found or empty for DBB. Skipping merge.
# No stock data found or empty for JKH. Skipping merge.
# No stock data found or empty for RZG. Skipping merge.
# No stock data found or empty for SCHG. Skipping merge.
# No stock data found or empty for SLYG. Skipping merge.
# No stock data found or empty for OSM. Skipping merge.
# No stock data found or empty for RYE. Skipping merge.
# No stock data found or empty for FXL. Skipping merge.
# No stock data found or empty for DDM. Skipping merge.
# No stock data found or empty for DNP. Skipping merge.
# No stock data found or empty for VIAB. Skipping merge.
# No stock data found or empty for JGBD. Skipping merge.
# No stock data found or empty for JGBL. Skipping merge.
# No stock data found or empty for JGBS. Skipping merge.
# No stock data found or empty for JGBT. Skipping merge.
# No stock data found or empty for SIJ. Skipping merge.
# No stock data found or empty for BUNL. Skipping merge.
# No stock data found or empty for ITLY. Skipping merge.
# No stock data found or empty for RVM. Skipping merge.
# No stock data found or empty for PGF. Skipping merge.
# No stock data found or empty for APF. Skipping merge.
# No stock data found or empty for GRI. Skipping merge.
# No stock data found or empty for JKL. Skipping merge.
# No stock data found or empty for PSCD. Skipping merge.
# No stock data found or empty for SLYV. Skipping merge.
# No stock data found or empty for JKK. Skipping merge.
# No stock data found or empty for EGI. Skipping merge.
# No stock data found or empty for GUR. Skipping merge.
# No stock data found or empty for ITM. Skipping merge.
# No stock data found or empty for MINT. Skipping merge.
# No stock data found or empty for MLN. Skipping merge.
# No stock data found or empty for CHOC. Skipping merge.
# No stock data found or empty for PGM. Skipping merge.
# No stock data found or empty for SCZ. Skipping merge.
# No stock data found or empty for SCO. Skipping merge.
# No stock data found or empty for WDTI. Skipping merge.
# No stock data found or empty for BF.A. Skipping merge.
# No stock data found or empty for FLAT. Skipping merge.
# No stock data found or empty for MLPL. Skipping merge.
# No stock data found or empty for UPW. Skipping merge.
# No stock data found or empty for VGLT. Skipping merge.
# No stock data found or empty for MFD. Skipping merge.
# No stock data found or empty for MSP. Skipping merge.
# No stock data found or empty for NPP. Skipping merge.
# No stock data found or empty for PFO. Skipping merge.
# No stock data found or empty for PHF. Skipping merge.
# No stock data found or empty for ALLB. Skipping merge.
# No stock data found or empty for BSL. Skipping merge.
# No stock data found or empty for CRBQ. Skipping merge.
# No stock data found or empty for FCO. Skipping merge.
# No stock data found or empty for CLM. Skipping merge.
# No stock data found or empty for FHY. Skipping merge.
# No stock data found or empty for DPU. Skipping merge.
# No stock data found or empty for VAW. Skipping merge.
# No stock data found or empty for PZI. Skipping merge.
# No stock data found or empty for RCD. Skipping merge.
# No stock data found or empty for WGA. Skipping merge.
# No stock data found or empty for GTU. Skipping merge.
# No stock data found or empty for UAE. Skipping merge.
# No stock data found or empty for FBZ. Skipping merge.
# No stock data found or empty for ADRU. Skipping merge.
# No stock data found or empty for ECF. Skipping merge.
# No stock data found or empty for ICLN. Skipping merge.
# No stock data found or empty for PSLV. Skipping merge.
# No stock data found or empty for XPL. Skipping merge.
# No stock data found or empty for CHII. Skipping merge.
# No stock data found or empty for DRV. Skipping merge.
# No stock data found or empty for EAD. Skipping merge.
# No stock data found or empty for PIM. Skipping merge.
# No stock data found or empty for NXR. Skipping merge.
# No stock data found or empty for VBFC. Skipping merge.
# No stock data found or empty for EMXX. Skipping merge.
# No stock data found or empty for FMK. Skipping merge.
# No stock data found or empty for GOF. Skipping merge.
# No stock data found or empty for UDOW. Skipping merge.
# No stock data found or empty for RYJ. Skipping merge.
# No stock data found or empty for NHTB. Skipping merge.
# No stock data found or empty for IYG. Skipping merge.
# No stock data found or empty for XHE. Skipping merge.
# No stock data found or empty for FEX. Skipping merge.
# No stock data found or empty for VEGI. Skipping merge.
# No stock data found or empty for PERM. Skipping merge.
# No stock data found or empty for ADZ. Skipping merge.
# No stock data found or empty for AGF. Skipping merge.
# No stock data found or empty for IPW. Skipping merge.
# No stock data found or empty for JPP. Skipping merge.
# No stock data found or empty for DSI. Skipping merge.
# No stock data found or empty for HAP. Skipping merge.
# No stock data found or empty for IGV. Skipping merge.
# No stock data found or empty for NIB. Skipping merge.
# No stock data found or empty for QTEC. Skipping merge.
# No stock data found or empty for RPV. Skipping merge.
# No stock data found or empty for CHIM. Skipping merge.
# No stock data found or empty for FDL. Skipping merge.
# No stock data found or empty for YAO. Skipping merge.
# No stock data found or empty for RPX. Skipping merge.
# No stock data found or empty for TAO. Skipping merge.
# No stock data found or empty for STPZ. Skipping merge.
# No stock data found or empty for WHX. Skipping merge.
# No stock data found or empty for DEF. Skipping merge.
# No stock data found or empty for FFR. Skipping merge.
# No stock data found or empty for MTK. Skipping merge.
# No stock data found or empty for JFC. Skipping merge.
# No stock data found or empty for TQQQ. Skipping merge.
# No stock data found or empty for VEU. Skipping merge.
# No stock data found or empty for VSS. Skipping merge.
# No stock data found or empty for EWSS. Skipping merge.
# No stock data found or empty for IVOP. Skipping merge.
# No stock data found or empty for SFLA. Skipping merge.
# No stock data found or empty for JJG. Skipping merge.
# No stock data found or empty for NHS. Skipping merge.
# No stock data found or empty for USD. Skipping merge.
# No stock data found or empty for SLVP. Skipping merge.
# No stock data found or empty for EPS. Skipping merge.
# No stock data found or empty for VXF. Skipping merge.
# No stock data found or empty for FLTB. Skipping merge.
# No stock data found or empty for DWM. Skipping merge.
# No stock data found or empty for EFV. Skipping merge.
# No stock data found or empty for MXI. Skipping merge.
# No stock data found or empty for JJM. Skipping merge.
# No stock data found or empty for CUT. Skipping merge.
# No stock data found or empty for BIS. Skipping merge.
# No stock data found or empty for ETF. Skipping merge.
# No stock data found or empty for RWX. Skipping merge.
# No stock data found or empty for IJJ. Skipping merge.
# No stock data found or empty for VO. Skipping merge.
# No stock data found or empty for VXZ. Skipping merge.
# No stock data found or empty for NMO. Skipping merge.
# No stock data found or empty for UMDD. Skipping merge.
# No stock data found or empty for GAZ. Skipping merge.
# No stock data found or empty for HTF. Skipping merge.
# No stock data found or empty for IRDMZ. Skipping merge.
# No stock data found or empty for TDI. Skipping merge.
# No stock data found or empty for IWC. Skipping merge.
# No stock data found or empty for IWS. Skipping merge.
# No stock data found or empty for PPT. Skipping merge.
# No stock data found or empty for TAS. Skipping merge.
# No stock data found or empty for VOE. Skipping merge.
# No stock data found or empty for TNDQ. Skipping merge.
# No stock data found or empty for FAB. Skipping merge.
# No stock data found or empty for IGM. Skipping merge.
# No stock data found or empty for XLG. Skipping merge.
# No stock data found or empty for RWR. Skipping merge.
# No stock data found or empty for AOK. Skipping merge.
# No stock data found or empty for HYLD. Skipping merge.
# No stock data found or empty for INP. Skipping merge.
# No stock data found or empty for CSJ. Skipping merge.
# No stock data found or empty for FWDB. Skipping merge.
# No stock data found or empty for VMBS. Skipping merge.
# No stock data found or empty for PIZ. Skipping merge.
# No stock data found or empty for TCHI. Skipping merge.
# No stock data found or empty for RXI. Skipping merge.
# No stock data found or empty for UGE. Skipping merge.
# No stock data found or empty for BOIL. Skipping merge.
# No stock data found or empty for KOLD. Skipping merge.
# No stock data found or empty for QLD. Skipping merge.
# No stock data found or empty for PSCU. Skipping merge.
# No stock data found or empty for REZ. Skipping merge.
# No stock data found or empty for BIB. Skipping merge.
# No stock data found or empty for CHIE. Skipping merge.
# No stock data found or empty for PWC. Skipping merge.
# No stock data found or empty for DEW. Skipping merge.
# No stock data found or empty for DLS. Skipping merge.
# No stock data found or empty for MTS. Skipping merge.
# No stock data found or empty for IYC. Skipping merge.
# No stock data found or empty for AMPS. Skipping merge.
# No stock data found or empty for ENGN. Skipping merge.
# No stock data found or empty for IYLD. Skipping merge.
# No stock data found or empty for PSCI. Skipping merge.
# No stock data found or empty for SVBL. Skipping merge.
# No stock data found or empty for SH. Skipping merge.
# No stock data found or empty for RDIB. Skipping merge.
# No stock data found or empty for EEME. Skipping merge.
# No stock data found or empty for HILO. Skipping merge.
# No stock data found or empty for LABC. Skipping merge.
# No stock data found or empty for ALFA. Skipping merge.
# No stock data found or empty for HYXU. Skipping merge.
# No stock data found or empty for QLTC. Skipping merge.
# No stock data found or empty for CWB. Skipping merge.
# No stock data found or empty for ENOR. Skipping merge.
# No stock data found or empty for CRED. Skipping merge.
# No stock data found or empty for GXF. Skipping merge.
# No stock data found or empty for SUB. Skipping merge.
# No stock data found or empty for CNDA. Skipping merge.
# No stock data found or empty for ATE. Skipping merge.
# No stock data found or empty for FILL. Skipping merge.
# No stock data found or empty for HBNK. Skipping merge.
# No stock data found or empty for IWV. Skipping merge.
# No stock data found or empty for ITLT. Skipping merge.
# No stock data found or empty for CRD.A. Skipping merge.
# No stock data found or empty for CEMB. Skipping merge.
# No stock data found or empty for SCHX. Skipping merge.
# No stock data found or empty for USMI. Skipping merge.
# No stock data found or empty for XOVR. Skipping merge.
# No stock data found or empty for AND. Skipping merge.
# No stock data found or empty for EMLP. Skipping merge.
# No stock data found or empty for MES. Skipping merge.
# No stock data found or empty for PLMT. Skipping merge.
# No stock data found or empty for AXJL. Skipping merge.
# No stock data found or empty for BRAQ. Skipping merge.
# No stock data found or empty for PSL. Skipping merge.
# No stock data found or empty for BCA. Skipping merge.
# No stock data found or empty for CFP. Skipping merge.
# No stock data found or empty for AQQ. Skipping merge.
# No stock data found or empty for FGM. Skipping merge.
# No stock data found or empty for SDOG. Skipping merge.
# No stock data found or empty for XSD. Skipping merge.
# No stock data found or empty for QQXT. Skipping merge.
# No stock data found or empty for FXD. Skipping merge.
# No stock data found or empty for FINU. Skipping merge.
# No stock data found or empty for FINZ. Skipping merge.
# No stock data found or empty for KXI. Skipping merge.
# No stock data found or empty for TDTF. Skipping merge.
# No stock data found or empty for TDTT. Skipping merge.
# No stock data found or empty for TILT. Skipping merge.
# No stock data found or empty for EMCD. Skipping merge.
# No stock data found or empty for FCHI. Skipping merge.
# No stock data found or empty for PBE. Skipping merge.
# No stock data found or empty for PDP. Skipping merge.
# No stock data found or empty for TAGS. Skipping merge.
# No stock data found or empty for UNL. Skipping merge.
# No stock data found or empty for PFXF. Skipping merge.
# No stock data found or empty for PGX. Skipping merge.
# No stock data found or empty for CTNN. Skipping merge.
# No stock data found or empty for RJA. Skipping merge.
# No stock data found or empty for ACWI. Skipping merge.
# No stock data found or empty for SCPB. Skipping merge.
# No stock data found or empty for VCO. Skipping merge.
# No stock data found or empty for TYD. Skipping merge.
# No stock data found or empty for INKM. Skipping merge.
# No stock data found or empty for FLOT. Skipping merge.
# No stock data found or empty for EPV. Skipping merge.
# No stock data found or empty for PEY. Skipping merge.
# No stock data found or empty for PFM. Skipping merge.
# No stock data found or empty for ACWV. Skipping merge.
# No stock data found or empty for QEH. Skipping merge.
# No stock data found or empty for VRD. Skipping merge.
# No stock data found or empty for CH. Skipping merge.
# No stock data found or empty for DOO. Skipping merge.
# No stock data found or empty for SMIN. Skipping merge.
# No stock data found or empty for RIT. Skipping merge.
# No stock data found or empty for IDXJ. Skipping merge.
# No stock data found or empty for LMCB. Skipping merge.
# No stock data found or empty for PXE. Skipping merge.
# No stock data found or empty for SLY. Skipping merge.
# No stock data found or empty for UTG. Skipping merge.
# No stock data found or empty for AFCB. Skipping merge.
# No stock data found or empty for BBRC. Skipping merge.
# No stock data found or empty for FRAK. Skipping merge.
# No stock data found or empty for HTR. Skipping merge.
# No stock data found or empty for PHO. Skipping merge.
# No stock data found or empty for SDOW. Skipping merge.
# No stock data found or empty for PHDG. Skipping merge.
# No stock data found or empty for GRU. Skipping merge.
# No stock data found or empty for IGU. Skipping merge.
# No stock data found or empty for ONEF. Skipping merge.
# No stock data found or empty for SJB. Skipping merge.
# No stock data found or empty for UJB. Skipping merge.
# No stock data found or empty for WEET. Skipping merge.
# No stock data found or empty for FRI. Skipping merge.
# No stock data found or empty for ACWX. Skipping merge.
# No stock data found or empty for LMLP. Skipping merge.
# No stock data found or empty for PBD. Skipping merge.
# No stock data found or empty for IYK. Skipping merge.
# No stock data found or empty for QID. Skipping merge.
# No stock data found or empty for CVY. Skipping merge.
# No stock data found or empty for DOM. Skipping merge.
# No stock data found or empty for MDIV. Skipping merge.
# No stock data found or empty for ENL. Skipping merge.
# No stock data found or empty for EWHS. Skipping merge.
# No stock data found or empty for MZF. Skipping merge.
# No stock data found or empty for NVSL. Skipping merge.
# No stock data found or empty for IDV. Skipping merge.
# No stock data found or empty for SGYPU. Skipping merge.
# No stock data found or empty for HOTRW. Skipping merge.
# No stock data found or empty for IPB. Skipping merge.
# No stock data found or empty for GHI. Skipping merge.
# No stock data found or empty for BKEPP. Skipping merge.
# No stock data found or empty for PBCP. Skipping merge.
# No stock data found or empty for DTO. Skipping merge.
# No stock data found or empty for GALTU. Skipping merge.
# No stock data found or empty for GNI. Skipping merge.
# No stock data found or empty for EEHB. Skipping merge.
# No stock data found or empty for IDHB. Skipping merge.
# No stock data found or empty for CHXF. Skipping merge.
# No stock data found or empty for FXZ. Skipping merge.
# No stock data found or empty for SCHA. Skipping merge.
# No stock data found or empty for SCHB. Skipping merge.
# No stock data found or empty for SCHC. Skipping merge.
# No stock data found or empty for SCHM. Skipping merge.
# No stock data found or empty for SCHV. Skipping merge.
# No stock data found or empty for SCHZ. Skipping merge.
# No stock data found or empty for SMN. Skipping merge.
# No stock data found or empty for RING. Skipping merge.
# No stock data found or empty for ATL. Skipping merge.
# No stock data found or empty for CELGZ. Skipping merge.
# No stock data found or empty for AXJS. Skipping merge.
# No stock data found or empty for EWCS. Skipping merge.
# No stock data found or empty for FDTS. Skipping merge.
# No stock data found or empty for GMFS. Skipping merge.
# No stock data found or empty for FSZ. Skipping merge.
# No stock data found or empty for KBWI. Skipping merge.
# No stock data found or empty for NFO. Skipping merge.
# No stock data found or empty for RBPAA. Skipping merge.
# No stock data found or empty for TLTE. Skipping merge.
# No stock data found or empty for RJZ. Skipping merge.
# No stock data found or empty for BDCL. Skipping merge.
# No stock data found or empty for FDD. Skipping merge.
# No stock data found or empty for VBR. Skipping merge.
# No stock data found or empty for FEU. Skipping merge.
# No stock data found or empty for FKU. Skipping merge.
# No stock data found or empty for FXN. Skipping merge.
# No stock data found or empty for TLTD. Skipping merge.
# No stock data found or empty for ECNS. Skipping merge.
# No stock data found or empty for KBWC. Skipping merge.
# No stock data found or empty for KBWR. Skipping merge.
# No stock data found or empty for PAF. Skipping merge.
# No stock data found or empty for QLTB. Skipping merge.
# No stock data found or empty for BPFHW. Skipping merge.
# No stock data found or empty for EMCR. Skipping merge.
# No stock data found or empty for JJU. Skipping merge.
# No stock data found or empty for COPX. Skipping merge.
# No stock data found or empty for DOD. Skipping merge.
# No stock data found or empty for ADRE. Skipping merge.
# No stock data found or empty for CBIN. Skipping merge.
# No stock data found or empty for CHIQ. Skipping merge.
# No stock data found or empty for EDEN. Skipping merge.
# No stock data found or empty for FCLF. Skipping merge.
# No stock data found or empty for MOAT. Skipping merge.
# No stock data found or empty for JXI. Skipping merge.
# No stock data found or empty for NXN. Skipping merge.
# No stock data found or empty for FRN. Skipping merge.
# No stock data found or empty for QQEW. Skipping merge.
# No stock data found or empty for PZA. Skipping merge.
# No stock data found or empty for SKF. Skipping merge.
# No stock data found or empty for EEML. Skipping merge.
# No stock data found or empty for IDLV. Skipping merge.
# No stock data found or empty for PKB. Skipping merge.
# No stock data found or empty for UHN. Skipping merge.
# No stock data found or empty for IHY. Skipping merge.
# No stock data found or empty for EDS. Skipping merge.
# No stock data found or empty for KBWP. Skipping merge.
# No stock data found or empty for SPFF. Skipping merge.
# No stock data found or empty for DTN. Skipping merge.
# No stock data found or empty for BRXX. Skipping merge.
# No stock data found or empty for JOF. Skipping merge.
# No stock data found or empty for MGV. Skipping merge.
# No stock data found or empty for GNMA. Skipping merge.
# No stock data found or empty for INTG. Skipping merge.
# No stock data found or empty for JSC. Skipping merge.
# No stock data found or empty for MONY. Skipping merge.
# No stock data found or empty for IXJ. Skipping merge.
# No stock data found or empty for DVYE. Skipping merge.
# No stock data found or empty for EFNL. Skipping merge.
# No stock data found or empty for HYMB. Skipping merge.
# No stock data found or empty for INXX. Skipping merge.
# No stock data found or empty for PMR. Skipping merge.
# No stock data found or empty for IDHQ. Skipping merge.
# No stock data found or empty for PDN. Skipping merge.
# No stock data found or empty for PXF. Skipping merge.
# No stock data found or empty for INCO. Skipping merge.
# No stock data found or empty for FKO. Skipping merge.
# No stock data found or empty for GMM. Skipping merge.
# No stock data found or empty for PFX. Skipping merge.
# No stock data found or empty for TDA. Skipping merge.
# No stock data found or empty for SNLN. Skipping merge.
# No stock data found or empty for STIP. Skipping merge.
# No stock data found or empty for VTIP. Skipping merge.
# No stock data found or empty for FNX. Skipping merge.
# No stock data found or empty for CACGU. Skipping merge.
# No stock data found or empty for PEK. Skipping merge.
# No stock data found or empty for PLW. Skipping merge.
# No stock data found or empty for RBY. Skipping merge.
# No stock data found or empty for TROVU. Skipping merge.
# No stock data found or empty for VYFC. Skipping merge.
# No stock data found or empty for QDYN. Skipping merge.
# No stock data found or empty for VGIT. Skipping merge.
# No stock data found or empty for VGSH. Skipping merge.
# No stock data found or empty for VONV. Skipping merge.
# No stock data found or empty for VRTB. Skipping merge.
# No stock data found or empty for VTHR. Skipping merge.
# No stock data found or empty for VTWO. Skipping merge.
# No stock data found or empty for VTWV. Skipping merge.
# No stock data found or empty for SGYPW. Skipping merge.
# No stock data found or empty for VLU. Skipping merge.
# No stock data found or empty for EMDI. Skipping merge.
# No stock data found or empty for EMEY. Skipping merge.
# No stock data found or empty for PSCC. Skipping merge.
# No stock data found or empty for PSCF. Skipping merge.
# No stock data found or empty for IYM. Skipping merge.
# No stock data found or empty for FXH. Skipping merge.
# No stock data found or empty for RPRXZ. Skipping merge.
# No stock data found or empty for RPRXW. Skipping merge.
# No stock data found or empty for ZIONW. Skipping merge.
# No stock data found or empty for DWAS. Skipping merge.
# No stock data found or empty for IMLP. Skipping merge.
# No stock data found or empty for MLPJ. Skipping merge.
# No stock data found or empty for TROVW. Skipping merge.
# No stock data found or empty for BICK. Skipping merge.
# No stock data found or empty for KNM. Skipping merge.
# No stock data found or empty for FHK. Skipping merge.
# No stock data found or empty for ASEA. Skipping merge.
# No stock data found or empty for FEP. Skipping merge.
# No stock data found or empty for PLND. Skipping merge.
# No stock data found or empty for PPLT. Skipping merge.
# No stock data found or empty for RYT. Skipping merge.
# No stock data found or empty for BAB. Skipping merge.
# No stock data found or empty for EWN. Skipping merge.
# No stock data found or empty for MRGR. Skipping merge.
# No stock data found or empty for KNOW. Skipping merge.
# No stock data found or empty for FXSG. Skipping merge.
# No stock data found or empty for MNA. Skipping merge.
# No stock data found or empty for VCV. Skipping merge.
# No stock data found or empty for USBI. Skipping merge.
# No stock data found or empty for GII. Skipping merge.
# No stock data found or empty for SQQQ. Skipping merge.
# No stock data found or empty for VIIX. Skipping merge.
# No stock data found or empty for DBV. Skipping merge.
# No stock data found or empty for EMCB. Skipping merge.
# No stock data found or empty for NORW. Skipping merge.
# No stock data found or empty for GURU. Skipping merge.
# No stock data found or empty for VXUS. Skipping merge.
# No stock data found or empty for HMG. Skipping merge.
# No stock data found or empty for VB. Skipping merge.
# No stock data found or empty for AADR. Skipping merge.
# No stock data found or empty for ADRD. Skipping merge.
# No stock data found or empty for PXSC. Skipping merge.
# No stock data found or empty for RWV. Skipping merge.
# No stock data found or empty for SVLC. Skipping merge.
# No stock data found or empty for ZFC. Skipping merge.
# No stock data found or empty for NEN. Skipping merge.
# No stock data found or empty for EGRW. Skipping merge.
# No stock data found or empty for FEM. Skipping merge.
# No stock data found or empty for FDI. Skipping merge.
# No stock data found or empty for FTT. Skipping merge.
# No stock data found or empty for JBR. Skipping merge.
# No stock data found or empty for SPHB. Skipping merge.
# No stock data found or empty for FORX. Skipping merge.
# No stock data found or empty for DFJ. Skipping merge.
# No stock data found or empty for FTA. Skipping merge.
# No stock data found or empty for FXO. Skipping merge.
# No stock data found or empty for PXSV. Skipping merge.
# No stock data found or empty for LEMB. Skipping merge.
# No stock data found or empty for BIZD. Skipping merge.
# No stock data found or empty for HTWO. Skipping merge.
# No stock data found or empty for XHS. Skipping merge.
# No stock data found or empty for CSD. Skipping merge.
# No stock data found or empty for ECON. Skipping merge.
# No stock data found or empty for ASMI. Skipping merge.
# No stock data found or empty for CHIX. Skipping merge.
# No stock data found or empty for KBWD. Skipping merge.
# No stock data found or empty for PSBH. Skipping merge.
# No stock data found or empty for AFK. Skipping merge.
# No stock data found or empty for AZIA. Skipping merge.
# No stock data found or empty for QDF. Skipping merge.
# No stock data found or empty for ICB. Skipping merge.
# No stock data found or empty for MVO. Skipping merge.
# No stock data found or empty for SMK. Skipping merge.
# No stock data found or empty for UMX. Skipping merge.
# No stock data found or empty for EWK. Skipping merge.
# No stock data found or empty for HYS. Skipping merge.
# No stock data found or empty for PIE. Skipping merge.
# No stock data found or empty for SJNK. Skipping merge.
# No stock data found or empty for EMHY. Skipping merge.
# No stock data found or empty for HYEM. Skipping merge.
# No stock data found or empty for QDEF. Skipping merge.
# No stock data found or empty for PEOP. Skipping merge.
# No stock data found or empty for IQDY. Skipping merge.
# No stock data found or empty for DZZ. Skipping merge.
# No stock data found or empty for EWO. Skipping merge.
# No stock data found or empty for RBL. Skipping merge.
# No stock data found or empty for GWL. Skipping merge.
# No stock data found or empty for SHV. Skipping merge.
# No stock data found or empty for ALD. Skipping merge.
# No stock data found or empty for EELV. Skipping merge.
# No stock data found or empty for ITF. Skipping merge.
# No stock data found or empty for IXC. Skipping merge.
# No stock data found or empty for KORU. Skipping merge.
# No stock data found or empty for JUNR. Skipping merge.
# No stock data found or empty for ROIQ. Skipping merge.
# No stock data found or empty for ROIQU. Skipping merge.
# No stock data found or empty for ROIQW. Skipping merge.
# No stock data found or empty for ADRA. Skipping merge.
# No stock data found or empty for FJP. Skipping merge.
# No stock data found or empty for RSXJ. Skipping merge.
# No stock data found or empty for DTD. Skipping merge.
# No stock data found or empty for ICN. Skipping merge.
# No stock data found or empty for PFIG. Skipping merge.
# No stock data found or empty for PHB. Skipping merge.
# No stock data found or empty for FTSL. Skipping merge.
# No stock data found or empty for EXE. Skipping merge.
# No stock data found or empty for TAOM. Skipping merge.
# No stock data found or empty for VIXY. Skipping merge.
# No stock data found or empty for ILTB. Skipping merge.
# No stock data found or empty for IOT. Skipping merge.
# No stock data found or empty for VFH. Skipping merge.
# No stock data found or empty for KBWB. Skipping merge.
# No stock data found or empty for MBB. Skipping merge.
# No stock data found or empty for TDIV. Skipping merge.
# No stock data found or empty for CROC. Skipping merge.
# No stock data found or empty for GDAY. Skipping merge.
# No stock data found or empty for VIOG. Skipping merge.
# No stock data found or empty for JMI. Skipping merge.
# No stock data found or empty for ESMC. Skipping merge.
# No stock data found or empty for CEW. Skipping merge.
# No stock data found or empty for EEV. Skipping merge.
# No stock data found or empty for KWT. Skipping merge.
# No stock data found or empty for XPH. Skipping merge.
# No stock data found or empty for PCEF. Skipping merge.
# No stock data found or empty for FXP. Skipping merge.
# No stock data found or empty for PFL. Skipping merge.
# No stock data found or empty for TTF. Skipping merge.
# No stock data found or empty for MINC. Skipping merge.
# No stock data found or empty for PGHY. Skipping merge.
# No stock data found or empty for SYLD. Skipping merge.
# No stock data found or empty for VWOB. Skipping merge.
# No stock data found or empty for JAXB. Skipping merge.
# No stock data found or empty for IJS. Skipping merge.
# No stock data found or empty for JPNL. Skipping merge.
# No stock data found or empty for EOC. Skipping merge.
# No stock data found or empty for BZQ. Skipping merge.
# No stock data found or empty for IAT. Skipping merge.
# No stock data found or empty for KRU. Skipping merge.
# No stock data found or empty for YMLI. Skipping merge.
# No stock data found or empty for GEX. Skipping merge.
# No stock data found or empty for IWB. Skipping merge.
# No stock data found or empty for PBW. Skipping merge.
# No stock data found or empty for WHZ. Skipping merge.
# No stock data found or empty for BJZ. Skipping merge.
# No stock data found or empty for BKK. Skipping merge.
# No stock data found or empty for BPK. Skipping merge.
# No stock data found or empty for IHF. Skipping merge.
# No stock data found or empty for CMBS. Skipping merge.
# No stock data found or empty for IAI. Skipping merge.
# No stock data found or empty for PXMC. Skipping merge.
# No stock data found or empty for EUSA. Skipping merge.
# No stock data found or empty for PGJ. Skipping merge.
# No stock data found or empty for IEZ. Skipping merge.
# No stock data found or empty for EWUS. Skipping merge.
# No stock data found or empty for VCR. Skipping merge.
# No stock data found or empty for FDM. Skipping merge.
# No stock data found or empty for DGRS. Skipping merge.
# No stock data found or empty for SARA. Skipping merge.
# No stock data found or empty for XMLV. Skipping merge.
# No stock data found or empty for FXC. Skipping merge.
# No stock data found or empty for BFOR. Skipping merge.
# No stock data found or empty for FWV. Skipping merge.
# No stock data found or empty for HSPX. Skipping merge.
# No stock data found or empty for AMJ. Skipping merge.
# No stock data found or empty for ZSL. Skipping merge.
# No stock data found or empty for DGRE. Skipping merge.
# No stock data found or empty for EWGS. Skipping merge.
# No stock data found or empty for FCAN. Skipping merge.
# No stock data found or empty for ARPI. Skipping merge.
# No stock data found or empty for CNYD. Skipping merge.
# No stock data found or empty for ETO. Skipping merge.
# No stock data found or empty for DBJP. Skipping merge.
# No stock data found or empty for DLN. Skipping merge.
# No stock data found or empty for YCS. Skipping merge.
# No stock data found or empty for BIL. Skipping merge.
# No stock data found or empty for IDU. Skipping merge.
# No stock data found or empty for SIVR. Skipping merge.
# No stock data found or empty for DBGR. Skipping merge.
# No stock data found or empty for ACCU. Skipping merge.
# No stock data found or empty for AGQ. Skipping merge.
# No stock data found or empty for EPOL. Skipping merge.
# No stock data found or empty for KFYP. Skipping merge.
# No stock data found or empty for INDY. Skipping merge.
# No stock data found or empty for DGS. Skipping merge.
# No stock data found or empty for EEMA. Skipping merge.
# No stock data found or empty for PJP. Skipping merge.
# No stock data found or empty for ELD. Skipping merge.
# No stock data found or empty for PNQI. Skipping merge.
# No stock data found or empty for IDX. Skipping merge.
# No stock data found or empty for RWXL. Skipping merge.
# No stock data found or empty for VHT. Skipping merge.
# No stock data found or empty for IYF. Skipping merge.
# No stock data found or empty for SIL. Skipping merge.
# No stock data found or empty for WDIV. Skipping merge.
# No stock data found or empty for EVAL. Skipping merge.
# No stock data found or empty for OLEM. Skipping merge.
# No stock data found or empty for EUO. Skipping merge.
# No stock data found or empty for GRF. Skipping merge.
# No stock data found or empty for VEGA. Skipping merge.
# No stock data found or empty for CLY. Skipping merge.
# ...
# No stock data found or empty for NAVB. Skipping merge.
# No stock data found or empty for NYMT. Skipping merge.
# No stock data found or empty for PANW. Skipping merge.
# No stock data found or empty for RENN. Skipping merge.
# No stock data found or empty for SPLK. Skipping merge.
# No stock data found or empty for SRNE. Skipping merge.
# No stock data found or empty for TJX. Skipping merge.
# No stock data found or empty for HTBX. Skipping merge.
# No stock data found or empty for ONCY. Skipping merge.
# No stock data found or empty for ACTG. Skipping merge.
# No stock data found or empty for AMC. Skipping merge.
# No stock data found or empty for AZO. Skipping merge.
# No stock data found or empty for BBD. Skipping merge.
# No stock data found or empty for BMRN. Skipping merge.
# No stock data found or empty for BNS. Skipping merge.
# No stock data found or empty for BRX. Skipping merge.
# No stock data found or empty for CANF. Skipping merge.
# No stock data found or empty for CMG. Skipping merge.
# No stock data found or empty for COF. Skipping merge.
# No stock data found or empty for DB. Skipping merge.
# No stock data found or empty for DPZ. Skipping merge.
# No stock data found or empty for EPR. Skipping merge.
# No stock data found or empty for FNF. Skipping merge.
# No stock data found or empty for GD. Skipping merge.
# No stock data found or empty for GNC. Skipping merge.
# No stock data found or empty for HAL. Skipping merge.
# No stock data found or empty for HDB. Skipping merge.
# No stock data found or empty for HIG. Skipping merge.
# No stock data found or empty for IBM. Skipping merge.
# No stock data found or empty for INTC. Skipping merge.
# No stock data found or empty for KSS. Skipping merge.
# No stock data found or empty for LYV. Skipping merge.
# No stock data found or empty for MPC. Skipping merge.
# No stock data found or empty for MTG. Skipping merge.
# No stock data found or empty for NOW. Skipping merge.
# No stock data found or empty for NXPI. Skipping merge.
# No stock data found or empty for PTEN. Skipping merge.
# No stock data found or empty for RDN. Skipping merge.
# No stock data found or empty for RLGY. Skipping merge.
# No stock data found or empty for RWT. Skipping merge.
# No stock data found or empty for SAN. Skipping merge.
# No stock data found or empty for SE. Skipping merge.
# No stock data found or empty for SLB. Skipping merge.
# No stock data found or empty for SNPS. Skipping merge.
# No stock data found or empty for WAL. Skipping merge.
# No stock data found or empty for WBS. Skipping merge.
# No stock data found or empty for WPC. Skipping merge.
# No stock data found or empty for AMD. Skipping merge.
# No stock data found or empty for ASNA. Skipping merge.
# No stock data found or empty for BGFV. Skipping merge.
# No stock data found or empty for BUD. Skipping merge.
# No stock data found or empty for CUK. Skipping merge.
# No stock data found or empty for DGX. Skipping merge.
# No stock data found or empty for ESEA. Skipping merge.
# No stock data found or empty for GLNG. Skipping merge.
# No stock data found or empty for H. Skipping merge.
# No stock data found or empty for HEI. Skipping merge.
# No stock data found or empty for KEY. Skipping merge.
# No stock data found or empty for KEYS. Skipping merge.
# No stock data found or empty for LOW. Skipping merge.
# No stock data found or empty for MEIP. Skipping merge.
# No stock data found or empty for MMM. Skipping merge.
# No stock data found or empty for MT. Skipping merge.
# No stock data found or empty for PENN. Skipping merge.
# No stock data found or empty for PFG. Skipping merge.
# No stock data found or empty for PLT. Skipping merge.
# No stock data found or empty for QCOM. Skipping merge.
# No stock data found or empty for RBS. Skipping merge.
# No stock data found or empty for RL. Skipping merge.
# No stock data found or empty for SPCB. Skipping merge.
# No stock data found or empty for SPWH. Skipping merge.
# No stock data found or empty for T. Skipping merge.
# No stock data found or empty for TCCO. Skipping merge.
# No stock data found or empty for TOL. Skipping merge.
# No stock data found or empty for TSCO. Skipping merge.
# No stock data found or empty for WIX. Skipping merge.
# No stock data found or empty for ACRX. Skipping merge.
# No stock data found or empty for ARNA. Skipping merge.
# No stock data found or empty for BSBR. Skipping merge.
# No stock data found or empty for BURL. Skipping merge.
# No stock data found or empty for CLRB. Skipping merge.
# No stock data found or empty for CRM. Skipping merge.
# No stock data found or empty for CSCO. Skipping merge.
# No stock data found or empty for DG. Skipping merge.
# No stock data found or empty for DLTR. Skipping merge.
# No stock data found or empty for ESNT. Skipping merge.
# No stock data found or empty for HLX. Skipping merge.
# No stock data found or empty for HP. Skipping merge.
# No stock data found or empty for HPQ. Skipping merge.
# No stock data found or empty for HSBC. Skipping merge.
# No stock data found or empty for JKS. Skipping merge.
# No stock data found or empty for JWN. Skipping merge.
# No stock data found or empty for LTRPA. Skipping merge.
# No stock data found or empty for MRNS. Skipping merge.
# No stock data found or empty for MTB. Skipping merge.
# No stock data found or empty for MU. Skipping merge.
# No stock data found or empty for NTAP. Skipping merge.
# No stock data found or empty for RF. Skipping merge.
# No stock data found or empty for SWK. Skipping merge.
# No stock data found or empty for TD. Skipping merge.
# No stock data found or empty for ULTA. Skipping merge.
# No stock data found or empty for WDAY. Skipping merge.
# No stock data found or empty for AVEO. Skipping merge.
# No stock data found or empty for BIG. Skipping merge.
# No stock data found or empty for CFG. Skipping merge.
# No stock data found or empty for CGNX. Skipping merge.
# No stock data found or empty for CJJD. Skipping merge.
# No stock data found or empty for DVAX. Skipping merge.
# No stock data found or empty for FDX. Skipping merge.
# No stock data found or empty for GLUU. Skipping merge.
# No stock data found or empty for JPM. Skipping merge.
# No stock data found or empty for MGNX. Skipping merge.
# No stock data found or empty for MRVL. Skipping merge.
# No stock data found or empty for NERV. Skipping merge.
# No stock data found or empty for NVS. Skipping merge.
# No stock data found or empty for REGN. Skipping merge.
# No stock data found or empty for RGA. Skipping merge.
# No stock data found or empty for UNFI. Skipping merge.
# No stock data found or empty for VEEV. Skipping merge.
# No stock data found or empty for VMW. Skipping merge.
# No stock data found or empty for W. Skipping merge.
# No stock data found or empty for WSM. Skipping merge.
# No stock data found or empty for YUM. Skipping merge.
# No stock data found or empty for BMY. Skipping merge.
# No stock data found or empty for CAR. Skipping merge.
# No stock data found or empty for IBB. Skipping merge.
# No stock data found or empty for XBI. Skipping merge.
# No stock data found or empty for MYL. Skipping merge.
# No stock data found or empty for NVDA. Skipping merge.
# No stock data found or empty for ABIO. Skipping merge.
# No stock data found or empty for AMRS. Skipping merge.
# No stock data found or empty for BABA. Skipping merge.
# No stock data found or empty for DFS. Skipping merge.
# No stock data found or empty for ERJ. Skipping merge.
# No stock data found or empty for FCAU. Skipping merge.
# No stock data found or empty for ITUB. Skipping merge.
# No stock data found or empty for IWM. Skipping merge.
# No stock data found or empty for LLY. Skipping merge.
# No stock data found or empty for LULU. Skipping merge.
# No stock data found or empty for MAR. Skipping merge.
# No stock data found or empty for OKE. Skipping merge.
# No stock data found or empty for OPK. Skipping merge.
# No stock data found or empty for SNV. Skipping merge.
# No stock data found or empty for TEVA. Skipping merge.
# No stock data found or empty for TGT. Skipping merge.
# No stock data found or empty for AXP. Skipping merge.
# No stock data found or empty for BTE. Skipping merge.
# No stock data found or empty for C. Skipping merge.
# No stock data found or empty for CAKE. Skipping merge.
# No stock data found or empty for DCI. Skipping merge.
# No stock data found or empty for EFX. Skipping merge.
# No stock data found or empty for EWU. Skipping merge.
# No stock data found or empty for FITB. Skipping merge.
# No stock data found or empty for HQY. Skipping merge.
# No stock data found or empty for MARK. Skipping merge.
# No stock data found or empty for NFLX. Skipping merge.
# No stock data found or empty for OSUR. Skipping merge.
# No stock data found or empty for PXD. Skipping merge.
# No stock data found or empty for RH. Skipping merge.
# No stock data found or empty for RSX. Skipping merge.
# No stock data found or empty for SM. Skipping merge.
# No stock data found or empty for SNY. Skipping merge.
# No stock data found or empty for TENX. Skipping merge.
# No stock data found or empty for WU. Skipping merge.
# No stock data found or empty for ZNGA. Skipping merge.
# No stock data found or empty for AEO. Skipping merge.
# No stock data found or empty for AMTD. Skipping merge.
# No stock data found or empty for ATVI. Skipping merge.
# No stock data found or empty for CMTL. Skipping merge.
# No stock data found or empty for CNK. Skipping merge.
# No stock data found or empty for CPB. Skipping merge.
# No stock data found or empty for DKS. Skipping merge.
# No stock data found or empty for EA. Skipping merge.
# No stock data found or empty for GOL. Skipping merge.
# No stock data found or empty for HT. Skipping merge.
# No stock data found or empty for INO. Skipping merge.
# No stock data found or empty for LPI. Skipping merge.
# No stock data found or empty for MAC. Skipping merge.
# No stock data found or empty for MCHP. Skipping merge.
# No stock data found or empty for MRK. Skipping merge.
# No stock data found or empty for NMIH. Skipping merge.
# No stock data found or empty for PFE. Skipping merge.
# No stock data found or empty for PLAY. Skipping merge.
# No stock data found or empty for PPC. Skipping merge.
# No stock data found or empty for RCL. Skipping merge.
# No stock data found or empty for SKT. Skipping merge.
# No stock data found or empty for SYY. Skipping merge.
# No stock data found or empty for TRGP. Skipping merge.
# No stock data found or empty for TUES. Skipping merge.
# No stock data found or empty for USB. Skipping merge.
# No stock data found or empty for ADSK. Skipping merge.
# No stock data found or empty for BAC. Skipping merge.
# No stock data found or empty for BP. Skipping merge.
# No stock data found or empty for CIEN. Skipping merge.
# No stock data found or empty for CMA. Skipping merge.
# No stock data found or empty for GIII. Skipping merge.
# No stock data found or empty for GOOG. Skipping merge.
# No stock data found or empty for GOOGL. Skipping merge.
# No stock data found or empty for JD. Skipping merge.
# No stock data found or empty for KBH. Skipping merge.
# No stock data found or empty for LTM. Skipping merge.
# No stock data found or empty for LVS. Skipping merge.
# No stock data found or empty for MFA. Skipping merge.
# No stock data found or empty for NAV. Skipping merge.
# No stock data found or empty for SCHW. Skipping merge.
# No stock data found or empty for SDRL. Skipping merge.
# No stock data found or empty for SEAS. Skipping merge.
# No stock data found or empty for SHIP. Skipping merge.
# No stock data found or empty for SJM. Skipping merge.
# No stock data found or empty for SPG. Skipping merge.
# No stock data found or empty for SPR. Skipping merge.
# No stock data found or empty for SQBG. Skipping merge.
# No stock data found or empty for SSL. Skipping merge.
# No stock data found or empty for TCO. Skipping merge.
# No stock data found or empty for TSN. Skipping merge.
# No stock data found or empty for VRML. Skipping merge.
# No stock data found or empty for WYNN. Skipping merge.
# No stock data found or empty for ALK. Skipping merge.
# No stock data found or empty for AVGO. Skipping merge.
# No stock data found or empty for CIDM. Skipping merge.
# No stock data found or empty for DIA. Skipping merge.
# No stock data found or empty for DIS. Skipping merge.
# No stock data found or empty for EBAY. Skipping merge.
# No stock data found or empty for ENT. Skipping merge.
# No stock data found or empty for F. Skipping merge.
# No stock data found or empty for FOSL. Skipping merge.
# No stock data found or empty for GLD. Skipping merge.
# No stock data found or empty for GM. Skipping merge.
# No stock data found or empty for GPS. Skipping merge.
# No stock data found or empty for IVR. Skipping merge.
# No stock data found or empty for MS. Skipping merge.
# No stock data found or empty for NBR. Skipping merge.
# No stock data found or empty for NVAX. Skipping merge.
# No stock data found or empty for OAS. Skipping merge.
# No stock data found or empty for QQQ. Skipping merge.
# No stock data found or empty for SBUX. Skipping merge.
# No stock data found or empty for TEN. Skipping merge.
# No stock data found or empty for TIF. Skipping merge.
# No stock data found or empty for TLT. Skipping merge.
# No stock data found or empty for TTPH. Skipping merge.
# No stock data found or empty for TUP. Skipping merge.
# No stock data found or empty for TWTR. Skipping merge.
# No stock data found or empty for WMT. Skipping merge.
# No stock data found or empty for XLE. Skipping merge.
# No stock data found or empty for XLF. Skipping merge.
# No stock data found or empty for XLK. Skipping merge.
# No stock data found or empty for AAL. Skipping merge.
# No stock data found or empty for AZN. Skipping merge.
# No stock data found or empty for CCL. Skipping merge.
# No stock data found or empty for CPE. Skipping merge.
# No stock data found or empty for CRC. Skipping merge.
# No stock data found or empty for DAL. Skipping merge.
# No stock data found or empty for DVP. Skipping merge.
# No stock data found or empty for FB. Skipping merge.
# No stock data found or empty for GILD. Skipping merge.
# No stock data found or empty for JBLU. Skipping merge.
# No stock data found or empty for LUV. Skipping merge.
# No stock data found or empty for MITT. Skipping merge.
# No stock data found or empty for NE. Skipping merge.
# No stock data found or empty for NIO. Skipping merge.
# No stock data found or empty for PCG. Skipping merge.
# No stock data found or empty for QEP. Skipping merge.
# No stock data found or empty for SAVE. Skipping merge.
# No stock data found or empty for VAL. Skipping merge.
# No stock data found or empty for XOM. Skipping merge.
# No stock data found or empty for XRT. Skipping merge.
# No stock data found or empty for AAPL. Skipping merge.
# No stock data found or empty for AMZN. Skipping merge.
# No stock data found or empty for BA. Skipping merge.
# No stock data found or empty for CHK. Skipping merge.
# No stock data found or empty for CONN. Skipping merge.
# No stock data found or empty for DGLY. Skipping merge.
# No stock data found or empty for FXI. Skipping merge.
# No stock data found or empty for GME. Skipping merge.
# No stock data found or empty for JNJ. Skipping merge.
# No stock data found or empty for LAKE. Skipping merge.
# No stock data found or empty for LTRPB. Skipping merge.
# No stock data found or empty for M. Skipping merge.
# No stock data found or empty for OXY. Skipping merge.
# No stock data found or empty for PVH. Skipping merge.
# No stock data found or empty for RIG. Skipping merge.
# No stock data found or empty for SIG. Skipping merge.
# No stock data found or empty for USO. Skipping merge.
# No stock data found or empty for VGK. Skipping merge.
# No stock data found or empty for WFC. Skipping merge.
# No stock data found or empty for WLL. Skipping merge.
# No stock data found or empty for CHS. Skipping merge.
# No stock data found or empty for CRIS. Skipping merge.
# No stock data found or empty for FIVE. Skipping merge.
# No stock data found or empty for HTZ. Skipping merge.
# No stock data found or empty for TSLA. Skipping merge.
# No stock data found or empty for UAL. Skipping merge.
# No stock data found or empty for GRUB. Skipping merge.
#
# Example: Merged data for AAPL head (sentiment and returns):

# %%
#Save correlation data
output_dir = '../data/processed/'
os.makedirs(output_dir, exist_ok=True)
for ticker, df in merged_data_for_correlation.items():
    df.to_csv(os.path.join(output_dir, f'{ticker}_merged_correlation_data.csv'))

print(f"\nSaved merged correlation data to {output_dir}")

#Save the overall correlation _df
correlation _df.to_csv(os.path.join(output_dir, 'overall_correlation_summary.csv'), index = False)
print(f"\Saved overall correlation summary to {ticker}")

# %% [markdown]
# # Perform Correlation Analysis

# %%
print("\n--- Performing Correlation Analysis ---")
correlation_results = {}

for ticker, df_merged in merged_data_for_correlation.items():
    if not df_merged.empty:
        # Calculate Pearson correlation
        correlation = df_merged['daily_avg_sentiment'].corr(df_merged['Daily_Return'])
        correlation_results[ticker] = correlation
        print(f"Correlation for {ticker}: {correlation:.4f}")
    else:
        print(f"Skipping correlation for {ticker}: No merged data available.")

print("\n--- Summary of Correlation Results ---")
correlation_df = pd.DataFrame(list(correlation_results.items()), columns=['Ticker', 'Sentiment_vs_Daily_Return_Correlation'])
print(correlation_df.sort_values(by='Sentiment_vs_Daily_Return_Correlation', ascending=False))

# Visualize correlations using a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Ticker', y='Sentiment_vs_Daily_Return_Correlation', data=correlation_df, palette='viridis')
plt.title('Correlation between Daily News Sentiment and Daily Stock Returns')
plt.xlabel('Stock Ticker')
plt.ylabel('Pearson Correlation Coefficient')
plt.ylim(-1, 1) # Set y-axis limits for correlation
plt.axhline(0, color='gray', linestyle='--', linewidth=0.7)
plt.show()

# --- Optional: Visualize Scatter Plot for a specific stock ---
ticker_to_plot_corr = 'AAPL' # Choose a ticker to inspect
if ticker_to_plot_corr in merged_data_for_correlation:
    df_plot_corr = merged_data_for_correlation[ticker_to_plot_corr]
    plt.figure(figsize=(10, 7))
    sns.scatterplot(x='daily_avg_sentiment', y='Daily_Return', data=df_plot_corr, alpha=0.6)
    plt.title(f'Daily News Sentiment vs. Daily Returns for {ticker_to_plot_corr}\n(Correlation: {correlation_results.get(ticker_to_plot_corr):.4f})')
    plt.xlabel('Daily Average Sentiment Score')
    plt.ylabel('Daily Stock Return (%)')
    plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)
    plt.axvline(0, color='grey', linestyle='--', linewidth=0.8)
    plt.show()
else:
    print(f"No merged data for {ticker_to_plot_corr} to plot correlation.")

# %% [markdown]
# # Interpretation and Next Steps

# %%
print("\n--- Interpretation of Correlation Results ---")
print("A correlation coefficient close to 1 indicates a strong positive linear relationship (higher sentiment associated with higher returns).")
print("A correlation coefficient close to -1 indicates a strong negative linear relationship (higher sentiment associated with lower returns).")
print("A correlation coefficient close to 0 indicates a weak or no linear relationship.")

print("\nKey Observations from Correlation Analysis:")
# Based on the output of the correlation_df and plots, you would write your observations here.
# For example:
# - "We observe a generally positive, but weak, correlation between daily news sentiment and daily stock returns across most tickers."
# - "AAPL shows a slightly stronger positive correlation than AMZN."
# - "The correlation values are relatively low, suggesting that daily average sentiment alone might not be a strong linear predictor of daily returns."
# - "This could imply that the market reacts to news in more complex ways, or that other factors (technical indicators, macroeconomic news) are more influential."

print("\nFurther Steps and Considerations:")
print("1. Lagging Effects: Investigate if news sentiment on day t correlates with stock returns on day t+1, t+2, etc. This involves shifting the stock return column.")
print("2. News Volume: Explore the correlation between the *volume* of news articles (not just sentiment) and stock movements.")
print("3. Sentiment Aggregation: Experiment with different sentiment aggregation methods (e.g., sum of positive/negative scores, weighted average, median).")
print("4. Advanced Sentiment: Consider more nuanced sentiment analysis (e.g., financial-specific lexicons, BERT-based models) beyond TextBlob/VADER.")
print("5. Non-linear Relationships: Correlation measures linear relationships. Non-linear patterns might exist, which could be explored with more advanced statistical models or machine learning.")
print("6. Feature Engineering: Combine news sentiment with the technical indicators calculated in Quantitative_Analysis.ipynb to create a richer feature set for predictive modeling.")
print("7. Hypothesis Testing: Use statistical tests (e.g., t-tests, p-values) to determine if the observed correlations are statistically significant.")
print("8. Strategy Development: Based on the observed correlations, formulate initial hypotheses for investment strategies that leverage news sentiment.")
